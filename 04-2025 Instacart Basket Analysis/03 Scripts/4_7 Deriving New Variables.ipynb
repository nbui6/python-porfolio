# %%
import pandas as pd
import numpy as np
import os

# %%
path = r'C:\Users\buitr\Documents\04-2025 Instacart Basket Analysis'

# %%
ords_prods_merge_path = os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_merge.pkl')

# %%
ords_prods_merge = pd.read_pickle(ords_prods_merge_path)

# %%
df = ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 16)

# %%
# Define a function
def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range product'
  else: return 'np.nan'

# %%
# Apply the function
df['price_range'] = df.apply(price_label, axis=1)
# Out:
# C:\Users\buitr\AppData\Local\Temp\ipykernel_24948\902492192.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
df['price_range'].value_counts(dropna=False)
# Out:
# price_range
# Mid-range product    652638
# Low-range product    338018
# High range             9344
# Name: count, dtype: int64

# %%
df
# Out:
#         Unnamed: 0  product_id                product_name  aisle_id  \
# 0                0           1  Chocolate Sandwich Cookies        61
# 1                0           1  Chocolate Sandwich Cookies        61
# 2                0           1  Chocolate Sandwich Cookies        61
# 3                0           1  Chocolate Sandwich Cookies        61
# 4                0           1  Chocolate Sandwich Cookies        61
# ...            ...         ...                         ...       ...
# 999995        2078        2078  Unsalted Pure Irish Butter        36
# 999996        2078        2078  Unsalted Pure Irish Butter        36
# 999997        2078        2078  Unsalted Pure Irish Butter        36
# 999998        2078        2078  Unsalted Pure Irish Butter        36
# 999999        2078        2078  Unsalted Pure Irish Butter        36
#
#         department_id  prices  order_id  user_id  order_number  \
# 0                  19     5.8   3139998      138            28
# ...

# %%
df['prices'].max()
# Out:
# 24.5

# %%
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product' 
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'
# Out:
# C:\Users\buitr\AppData\Local\Temp\ipykernel_24948\3192052085.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df['price_range_loc'].value_counts(dropna=False)
# Out:
# price_range_loc
# Mid-range product     652638
# Low-range product     338018
# High-range product      9344
# Name: count, dtype: int64

# %%
ords_prods_merge['orders_day_of_week'].value_counts(dropna=False)
# Out:
# orders_day_of_week
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: count, dtype: int64

# %%
# Create Busiest day column
result = []

for value in ords_prods_merge["orders_day_of_week"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Busiest day',
#  'Least busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
ords_prods_merge['busiest_day'] = result

# %%
ords_prods_merge
# Out:
#           Unnamed: 0  product_id                product_name  aisle_id  \
# 0                  0           1  Chocolate Sandwich Cookies        61
# 1                  0           1  Chocolate Sandwich Cookies        61
# 2                  0           1  Chocolate Sandwich Cookies        61
# 3                  0           1  Chocolate Sandwich Cookies        61
# 4                  0           1  Chocolate Sandwich Cookies        61
# ...              ...         ...                         ...       ...
# 32404854       49692       49688      Fresh Foaming Cleanser        73
# 32404855       49692       49688      Fresh Foaming Cleanser        73
# 32404856       49692       49688      Fresh Foaming Cleanser        73
# 32404857       49692       49688      Fresh Foaming Cleanser        73
# 32404858       49692       49688      Fresh Foaming Cleanser        73
#
#           department_id  prices  order_id  user_id  order_number  \
# ...

# %%
ords_prods_merge['busiest_day'].value_counts(dropna=False)
# Out:
# busiest_day
# Regularly busy    22416875
# Busiest day        6204182
# Least busy         3783802
# Name: count, dtype: int64

# %%
ords_prods_merge['busiest_day'].value_counts()
# Out:
# busiest_day
# Regularly busy    22416875
# Busiest day        6204182
# Least busy         3783802
# Name: count, dtype: int64

# %%
#  “Busiest day” to become “Busiest days”
# two slowest days
ords_prods_merge['orders_day_of_week'].value_counts(dropna=False)
# Out:
# orders_day_of_week
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: count, dtype: int64

# %%
new_result = []

for value in ords_prods_merge["orders_day_of_week"]:
  if value in [0, 1]:
    new_result.append("Busiest days")
  elif value in [3, 4]:
    new_result.append("Slowest days")
  else:
    new_result.append("Regularly busy")

# %%
ords_prods_merge['busiest_days'] = new_result

# %%
ords_prods_merge['busiest_days'].value_counts(dropna=False)
# Out:
# busiest_days
# Regularly busy    12916111
# Busiest days      11864412
# Slowest days       7624336
# Name: count, dtype: int64

# %%
# Check the values of this new column for accuracy. Note any observations in markdown format.
# Total rows with value 0 or 1 → "Busiest days"
busiest_days = ords_prods_merge[ords_prods_merge["orders_day_of_week"].isin([0, 1])].shape[0]

# Total rows with value 3 or 4 → "Slowest days"
slowest_days = ords_prods_merge[ords_prods_merge["orders_day_of_week"].isin([3, 4])].shape[0]

# All other values → "Regularly busy"
regular_days = ords_prods_merge[ords_prods_merge["orders_day_of_week"].isin([2, 5, 6])].shape[0]

# Print to compare
print("Busiest days:", busiest_days)
print("Slowest days:", slowest_days)
print("Regularly busy:", regular_days)
# Out:
# Busiest days: 11864412
# Slowest days: 7624336
# Regularly busy: 12916111

# %%
ords_prods_merge.head()
# Out:
#    Unnamed: 0  product_id                product_name  aisle_id  \
# 0           0           1  Chocolate Sandwich Cookies        61
# 1           0           1  Chocolate Sandwich Cookies        61
# 2           0           1  Chocolate Sandwich Cookies        61
# 3           0           1  Chocolate Sandwich Cookies        61
# 4           0           1  Chocolate Sandwich Cookies        61
#
#    department_id  prices  order_id  user_id  order_number  orders_day_of_week  \
# 0             19     5.8   3139998      138            28                   6
# 1             19     5.8   1977647      138            30                   6
# 2             19     5.8    389851      709             2                   0
# 3             19     5.8    652770      764             1                   3
# 4             19     5.8   1813452      764             3                   4
#
#    order_hour_of_day  days_since_prior_order  new_customer  add_to_cart_order  \
# ...

# %%
ords_prods_merge['order_hour_of_day'].value_counts(dropna=False)
# Out:
# order_hour_of_day
# 10    2761760
# 11    2736140
# 14    2689136
# 15    2662144
# 13    2660954
# 12    2618532
# 16    2535202
# 9     2454203
# 17    2087654
# 8     1718118
# 18    1636502
# 19    1258305
# 20     976156
# 7      891054
# 21     795637
# 22     634225
# 23     402316
# 6      290493
# 0      218769
# 1      115700
# 5       87961
# 2       69375
# 4       53242
# 3       51281
# Name: count, dtype: int64

# %%
busiest_period_of_day = []
for value in ords_prods_merge["order_hour_of_day"]:
    if value in [10, 11, 14, 15, 13, 12, 16, 9]:
        busiest_period_of_day.append('most_orders')
    elif value in [17, 8, 18, 19, 20, 7, 21, 22]:
        busiest_period_of_day.append('average_orders')
    else:
        busiest_period_of_day.append('fewest_orders')

# %%
ords_prods_merge['busiest_period_of_day'] = busiest_period_of_day

# %%
# Print the frequency for this new column.
ords_prods_merge['busiest_period_of_day'].value_counts(dropna=False)
# Out:
# busiest_period_of_day
# most_orders       21118071
# average_orders     9997651
# fewest_orders      1289137
# Name: count, dtype: int64

# %%
ords_prods_merge.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_merge_busiest_day_hour.pkl'))
