# %%
import pandas as pd
import numpy as np
import os

# %%
path = r'C:\Users\buitr\Documents\04-2025 Instacart Basket Analysis'

# %%
# 3. import the orders_products_combined dataframe from the pickle file
opc_path = os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_combined.pkl')

# %%
df_opc = pd.read_pickle(opc_path)

# %%
# 4. Check the shape of the imported dataframe
df_opc.shape
# Out:
# (32434489, 14)

# %%
clean_prods_no_dups_path = os.path.join(path, '02 Data', 'Prepared Data', 'clean_prods_no_dups.csv')

# %%
df_prods = pd.read_csv(clean_prods_no_dups_path, index_col = False)

# %%
df_prods.shape
# Out:
# (49672, 6)

# %%
df_prods
# Out:
#        Unnamed: 0  product_id  \
# 0               0           1
# 1               1           2
# 2               2           3
# 3               3           4
# 4               4           5
# ...           ...         ...
# 49667       49688       49684
# 49668       49689       49685
# 49669       49690       49686
# 49670       49691       49687
# 49671       49692       49688
#
#                                             product_name  aisle_id  \
# 0                             Chocolate Sandwich Cookies        61
# 1                                       All-Seasons Salt       104
# 2                   Robust Golden Unsweetened Oolong Tea        94
# 3      Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4                              Green Chile Anytime Sauce         5
# ...                                                  ...       ...
# 49667          Vodka, Triple Distilled, Twist of Vanilla       124
# ...

# %%
df_opc
# Out:
#           Unnamed: 0.1  Unnamed: 0  order_id  user_id eval_set  order_number  \
# 0                    0           0   2539329        1    prior             1
# 1                    0           0   2539329        1    prior             1
# 2                    0           0   2539329        1    prior             1
# 3                    0           0   2539329        1    prior             1
# 4                    0           0   2539329        1    prior             1
# ...                ...         ...       ...      ...      ...           ...
# 32434484       3421081     3421081   2977660   206209    prior            13
# 32434485       3421081     3421081   2977660   206209    prior            13
# 32434486       3421081     3421081   2977660   206209    prior            13
# 32434487       3421081     3421081   2977660   206209    prior            13
# 32434488       3421081     3421081   2977660   206209    prior            13
#
# ...

# %%
df_opc = df_opc.drop('_merge', axis = 1)

# %%
# 5. Determine a suitable way to combine the orders_products_combined dataframe
df_ords_prods_merge = df_prods.merge(df_opc, on = 'product_id', indicator = True)

# %%
df_ords_prods_merge
# Out:
#           Unnamed: 0_x  product_id                product_name  aisle_id  \
# 0                    0           1  Chocolate Sandwich Cookies        61
# 1                    0           1  Chocolate Sandwich Cookies        61
# 2                    0           1  Chocolate Sandwich Cookies        61
# 3                    0           1  Chocolate Sandwich Cookies        61
# 4                    0           1  Chocolate Sandwich Cookies        61
# ...                ...         ...                         ...       ...
# 32404854         49692       49688      Fresh Foaming Cleanser        73
# 32404855         49692       49688      Fresh Foaming Cleanser        73
# 32404856         49692       49688      Fresh Foaming Cleanser        73
# 32404857         49692       49688      Fresh Foaming Cleanser        73
# 32404858         49692       49688      Fresh Foaming Cleanser        73
#
#           department_id  prices  Unnamed: 0.1  Unnamed: 0_y  order_id  \
# ...

# %%
df_ords_prods_merge.shape
# Out:
# (32404859, 19)

# %%
# 6. Confirm the results of the merge using the merge flag
df_ords_prods_merge['_merge'].value_counts()
# Out:
# _merge
# both          32404859
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %%
# 7. Export the newly created dataframe as ords_prods_merge in a suitable format
df_ords_prods_merge.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_merge.pkl'))
