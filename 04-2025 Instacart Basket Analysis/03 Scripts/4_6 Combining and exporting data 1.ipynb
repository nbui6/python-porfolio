# %%
import pandas as pd
import numpy as np
import os

# %%
path = r'C:\Users\buitr\Documents\04-2025 Instacart Basket Analysis'

# %%
prods_path = os.path.join(path, '02 Data', 'Prepared Data', 'clean_prods_no_dups.csv')

# %%
ords_path = os.path.join(path, '02 Data', 'Prepared Data', 'clean_ords_no_dups.csv')

# %%
df_prods = pd.read_csv(prods_path, index_col = False)

# %%
df_ords = pd.read_csv(ords_path, index_col = False)

# %%
orders_products_prior_path = os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_prior.csv')

# %%
# 3. Import the data set into Jupyter as a new dataframe: df_ords_prior.
df_ords_prior = pd.read_csv(orders_products_prior_path, index_col = False)

# %%
# Check the dimensions of the imported dataframe.
df_ords_prior
# Out:
#           order_id  product_id  add_to_cart_order  reordered
# 0                2       33120                  1          1
# 1                2       28985                  2          1
# 2                2        9327                  3          0
# 3                2       45918                  4          1
# 4                2       30035                  5          0
# ...            ...         ...                ...        ...
# 32434484   3421083       39678                  6          1
# 32434485   3421083       11352                  7          0
# 32434486   3421083        4600                  8          0
# 32434487   3421083       24852                  9          1
# 32434488   3421083        5020                 10          1
#
# [32434489 rows x 4 columns]

# %%
df_ords_prior.describe()
# Out:
#            order_id    product_id  add_to_cart_order     reordered
# count  3.243449e+07  3.243449e+07       3.243449e+07  3.243449e+07
# mean   1.710749e+06  2.557634e+04       8.351076e+00  5.896975e-01
# std    9.873007e+05  1.409669e+04       7.126671e+00  4.918886e-01
# min    2.000000e+00  1.000000e+00       1.000000e+00  0.000000e+00
# 25%    8.559430e+05  1.353000e+04       3.000000e+00  0.000000e+00
# 50%    1.711048e+06  2.525600e+04       6.000000e+00  1.000000e+00
# 75%    2.565514e+06  3.793500e+04       1.100000e+01  1.000000e+00
# max    3.421083e+06  4.968800e+04       1.450000e+02  1.000000e+00

# %%
df_ords_prior.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
pd.merge(df_ords,df_ords_prior, on = ['order_id'], indicator = True)
# Out:
#           Unnamed: 0.1  Unnamed: 0  order_id  user_id eval_set  order_number  \
# 0                    0           0   2539329        1    prior             1
# 1                    0           0   2539329        1    prior             1
# 2                    0           0   2539329        1    prior             1
# 3                    0           0   2539329        1    prior             1
# 4                    0           0   2539329        1    prior             1
# ...                ...         ...       ...      ...      ...           ...
# 32434484       3421081     3421081   2977660   206209    prior            13
# 32434485       3421081     3421081   2977660   206209    prior            13
# 32434486       3421081     3421081   2977660   206209    prior            13
# 32434487       3421081     3421081   2977660   206209    prior            13
# 32434488       3421081     3421081   2977660   206209    prior            13
#
# ...

# %%
df_ords_prior.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
df_ords.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  order_id  user_id eval_set  order_number  \
# 0             0           0   2539329        1    prior             1
# 1             1           1   2398795        1    prior             2
# 2             2           2    473747        1    prior             3
# 3             3           3   2254736        1    prior             4
# 4             4           4    431534        1    prior             5
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order  new_customer
# 0                   2                  8                     NaN          True
# 1                   3                  7                    15.0         False
# 2                   3                 12                    21.0         False
# 3                   4                  7                    29.0         False
# 4                   4                 15                    28.0         False

# %%
df_ords.shape
# Out:
# (3421083, 10)

# %%
df_ords_prior.shape
# Out:
# (32434489, 4)

# %%
# Merge the dataframe with your df_ords dataframe.
# Use the indicator argument to check whether there was a full match between the two dataframes.
df_merged_large = df_ords.merge(df_ords_prior, on = 'order_id', indicator = True)

# %%
df_merged_large.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  order_id  user_id eval_set  order_number  \
# 0             0           0   2539329        1    prior             1
# 1             0           0   2539329        1    prior             1
# 2             0           0   2539329        1    prior             1
# 3             0           0   2539329        1    prior             1
# 4             0           0   2539329        1    prior             1
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order  \
# 0                   2                  8                     NaN
# 1                   2                  8                     NaN
# 2                   2                  8                     NaN
# 3                   2                  8                     NaN
# 4                   2                  8                     NaN
#
#    new_customer  product_id  add_to_cart_order  reordered _merge
# 0          True         196                  1          0   both
# ...

# %%
df_merged_large['_merge'].value_counts()
# Out:
# _merge
# both          32434489
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %%
df_merged_large_outer = df_ords.merge(df_ords_prior, on = 'order_id', indicator = True, how = 'outer')

# %%
df_merged_large_outer['_merge'].value_counts()
# Out:
# _merge
# both          32434489
# left_only       206209
# right_only           0
# Name: count, dtype: int64

# %%
df_merged_large.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_combined.pkl'))

# %%
df_merged_large.shape
# Out:
# (32434489, 14)
